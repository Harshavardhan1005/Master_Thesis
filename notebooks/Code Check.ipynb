# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_pacf
import seaborn as sns

# %%
cd ..
# Out:
# /home/raj/PycharmProjects/Master_Thesis

# %%
df = pd.read_csv('merged_data/train.csv')

# %%
df.head()
# Out:
#    Week_Day  Week  Hour  Minutes  Seconds  Average_Speed  Clouds   Temp  \
# 0         2    35     5        6       17           26.1       0  284.6
# 1         2    35     6        1       53           25.2       0  283.9
# 2         2    35     7       22       19           22.9      20  283.9
# 3         2    35     7       49       28           17.1      20  283.9
# 4         2    35     8       37       22           21.1      75  284.9
#
#    Wind_deg  Wind_speed  Rain_1h  Rain_3h  Snow_1h  Snow_3h  travel_time
# 0        60         2.1      0.0      0.0      0.0      0.0          9.7
# 1        60         2.6      0.0      0.0      0.0      0.0          6.3
# 2        50         2.6      0.0      0.0      0.0      0.0          6.9
# 3        50         2.6      0.0      0.0      0.0      0.0          5.4
# 4        60         3.6      0.0      0.0      0.0      0.0          7.5

# %%
plot_pacf(df['travel_time']);
# Out:
# /home/raj/anaconda3/envs/forecast/lib/python3.7/site-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
df.corr()
# Out:
#                Week_Day      Week      Hour   Minutes   Seconds  \
# Week_Day       1.000000 -0.038064  0.008764 -0.002060 -0.018267
# Week          -0.038064  1.000000 -0.004822  0.012103  0.014590
# Hour           0.008764 -0.004822  1.000000 -0.008872 -0.043035
# Minutes       -0.002060  0.012103 -0.008872  1.000000  0.022106
# Seconds       -0.018267  0.014590 -0.043035  0.022106  1.000000
# Average_Speed  0.029954 -0.015647 -0.009841  0.011829 -0.027261
# Clouds         0.019399  0.070989 -0.154343 -0.003619  0.015902
# Temp          -0.039027  0.217367  0.137994  0.024247 -0.018657
# Wind_deg      -0.002997 -0.065614  0.054264  0.006101  0.014555
# Wind_speed    -0.094762  0.015150  0.036402 -0.010035  0.032165
# Rain_1h        0.065207  0.000822 -0.005473 -0.039695 -0.019052
# Rain_3h             NaN       NaN       NaN       NaN       NaN
# Snow_1h       -0.039307  0.047071 -0.010303  0.014647 -0.013412
# Snow_3h             NaN       NaN       NaN       NaN       NaN
# ...

# %%
sns.countplot(df['Hour'])
# Out:
# /home/raj/anaconda3/envs/forecast/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Hour', ylabel='count'>

# %%
sns.countplot(df['Week_Day'])
# Out:
# /home/raj/anaconda3/envs/forecast/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Week_Day', ylabel='count'>

# %%
df
# Out:
#       Week_Day  Week  Hour  Minutes  Seconds  Average_Speed  Clouds   Temp  \
# 0            2    35     5        6       17           26.1       0  284.6
# 1            2    35     6        1       53           25.2       0  283.9
# 2            2    35     7       22       19           22.9      20  283.9
# 3            2    35     7       49       28           17.1      20  283.9
# 4            2    35     8       37       22           21.1      75  284.9
# ...        ...   ...   ...      ...      ...            ...     ...    ...
# 2651         0     5     1       19        6           18.6      75  273.7
# 2652         0     5     2       17       11           18.7      90  273.5
# 2653         0     5     4       56        8           20.7      90  274.6
# 2654         0     5     5       42        3           22.7      90  275.3
# 2655         0     5     6       15        3           22.6      90  275.9
#
# ...

# %%
df.groupby(['Week'])['travel_time'].mean()
# Out:
# Week
# 1     6.497183
# 2     6.613986
# 3     6.158824
# 4     5.944667
# 5     5.700000
# 35    7.364706
# 36    6.178977
# 37    6.170659
# 38    6.332558
# 39    6.355814
# 40    6.157576
# 41    6.504730
# 42    6.142384
# 43    6.220930
# 44    6.237143
# 45    6.132061
# 46    6.317901
# 47    6.200775
# 48    6.066667
# 49    6.362857
# 50    6.657778
# 51    6.417708
# 52    6.300000
# Name: travel_time, dtype: float64

# %%
sns.countplot(df[df['Week']==35].groupby(['Week_Day','Week'])['travel_time'].mean())
# Out:
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='travel_time', ylabel='count'>

# %%
# Less number of trips are taken on weekends which is reduced by more than 50%

# possibility of travel time less than 4 min from 12:00 to 07:00

# 35th week(september ist week) average time is greater that 7.3 minutes

# 4th and 5th week (january last week and feb first week average time os less than 5.9 minutes

# There are some trips which are very less compared to othzer day bcos of any event or strike or technical problem

# %%
import joblib
from sklearn.ensemble import RandomForestRegressor

# %%
train_data_path = 'merged_data/test.csv'
test_data_path = 'merged_data/train.csv'
model_dir_path = 'models/model.joblib'
target = 'travel_time'

# %%
train = pd.read_csv(train_data_path, sep=",")
test = pd.read_csv(test_data_path, sep=",")

train_y = train[target]
test_y = test[target]

train_x = train.drop(target, axis=1)
test_x = test.drop(target, axis=1)

# %%
rf = RandomForestRegressor()

# %%
rf.fit(train_x,train_y)
# Out:
# RandomForestRegressor()

# %%
import shap
shap_values = shap.TreeExplainer(rf).shap_values(train_x)
shap.summary_plot(shap_values, train_x, plot_type="bar")

# %%
import matplotlib.pyplot as plt
f = plt.figure()
shap.summary_plot(shap_values, train_x)

# %%
# Initialize your Jupyter notebook with initjs(), otherwise you will get an error message.
shap.initjs()

# Write in a function
def shap_plot(j):
    explainerModel = shap.TreeExplainer(rf)
    shap_values_Model = explainerModel.shap_values(S)
    p = shap.force_plot(explainerModel.expected_value, shap_values_Model[j], S.iloc[[j]])
    return(p)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...
